# %%
import requests
from bs4 import BeautifulSoup
import pprint

# %%
def main():
    num_pages = int(input('Choose the number of pages you want to crawl: '))
    for i in range(1,num_pages+1):
        res = requests.get(f'https://news.ycombinator.com/news?p={i}')
        soup = BeautifulSoup(res.text, 'html.parser')
        links = soup.select('.storylink')
        subtext = soup.select('.subtext')
        pprint.pprint((create_custom_hn(links, subtext)))

def sort_stories_by_votes(hnlist):
    return sorted(hnlist, key= lambda k:k['votes'],reverse=True)

def create_custom_hn(links, subtext):
    hn = []
    for idx, item in enumerate(links):
        title = item.getText()
        href = item.get('href', None)
        vote = subtext[idx].select('.score')
        if len(vote):
            points = int(vote[0].getText().strip(' points'))
            if points > 99:
                hn.append({'title': title, 'link': href, 'votes': points})
    return sort_stories_by_votes(hn)

main()
# Out:
# Choose the number of pages you want to crawl: 3
# [{'link': 'https://earthly.dev/blog/thought-leaders/',
#   'title': "Don't Feed the Thought Leaders",
#   'votes': 566},
#  {'link': 'http://mathman.biz/materials/Calculus%20By%20and%20For%20Young%20People%20Worksheets.pdf',
#   'title': 'Calculus for Seven Year Olds [pdf]',
#   'votes': 212},
#  {'link': 'https://www.openhistoricalmap.org/',
#   'title': 'OpenHistoricalMap',
#   'votes': 174},
#  {'link': 'https://www.nature.com/articles/d41586-021-01560-4',
#   'title': 'Mysterious fast radio bursts come in two distinct flavours',
#   'votes': 164},
#  {'link': 'https://calpaterson.com/fraud.html',
#   'title': 'No general method to detect fraud',
#   'votes': 147},
#  {'link': 'https://play.google.com/store/apps/details?id=com.bandcamp.android&hl=en_US&gl=US',
#   'title': "Bandcamp's app is no longer listed on Google Play",
#   'votes': 122},
#  {'link': 'https://status.aws.amazon.com/#EU_block',
#   'title': 'AWS Frankfurt incident',
#   'votes': 117},
#  {'link': 'https://www.scientificamerican.com/article/physicists-measure-the-gravitational-force-between-the-smallest-masses-yet/',
#   'title': 'Physicists measure the gravitational force between the smallest '
#            'masses yet',
#   'votes': 116},
#  {'link': 'https://www.fda.gov/drugs/drug-safety-and-availability/fda-approves-drug-treat-smallpox',
#   'title': 'FDA approves drug to treat smallpox',
#   'votes': 113},
#  {'link': 'item?id=27461564',
#   'title': 'Launch HN: Okay (YC W20) – Analytics for engineering teams',
#   'votes': 111}]
# [{'link': 'https://potential.app/ios-15-humane',
#   'title': 'iOS 15 Humane',
#   'votes': 1173},
#  {'link': 'https://stripe.com/tax', 'title': 'Stripe Tax', 'votes': 901},
#  {'link': 'https://jmmv.dev/2021/04/always-be-quitting.html',
#   'title': 'Always Be Quitting',
#   'votes': 624},
#  {'link': 'https://ez.substack.com/p/the-work-from-home-future-is-destroying',
#   'title': "The work-from-home future is destroying bosses' brains",
#   'votes': 471},
#  {'link': 'https://tryapl.org', 'title': 'Try APL', 'votes': 359},
#  {'link': 'https://keathley.io/blog/good-and-bad-elixir.html',
#   'title': 'Good and Bad Elixir',
#   'votes': 328},
#  {'link': 'https://spectrum.ieee.org/cars-that-think/transportation/advanced-cars/software-eating-car',
#   'title': 'Software is eating the car',
#   'votes': 269},
#  {'link': 'https://blog.mozilla.org/en/mozilla/privacy-analysis-of-floc/',
#   'title': 'Privacy Analysis of FLoC',
#   'votes': 253},
#  {'link': 'https://bugs.chromium.org/p/chromium/issues/detail?id=1090393#c75',
#   'title': "Chrome abandons 'simplified domain experiment' in omnibar",
#   'votes': 228},
#  {'link': 'https://www.justice.gov/usao-wdwa/pr/husband-amazon-employee-sentenced-prison-insider-trading-amazon-stock',
#   'title': 'Husband of Amazon employee sentenced to prison for insider trading '
#            'Amazon stock',
#   'votes': 201},
#  {'link': 'https://www.platformer.news/p/will-apple-mail-end-the-newsletter',
#   'title': 'Will Apple Mail threaten the newsletter boom?',
#   'votes': 184},
#  {'link': 'https://www.jeffgeerling.com/blog/2021/moving-my-home-media-library-itunes-jellyfin-and-infuse',
#   'title': 'Moving my home media library from iTunes to Jellyfin and Infuse',
#   'votes': 164},
#  {'link': 'https://instantdomainsearch.com/engineering/how-to-use-fasttext-for-instant-translations',
#   'title': 'Using aligned word vectors for instant translations with Python '
#            'and Rust',
#   'votes': 102}]
# [{'link': 'http://paulgraham.com/own.html',
#   'title': 'A Project of One’s Own',
#   'votes': 716},
#  {'link': 'https://fragile-credences.github.io/scihub-proxy/',
#   'title': 'How to circumvent Sci-Hub ISP block',
#   'votes': 466},
#  {'link': 'https://iism.org/article/developers-can-t-fix-bad-management-57',
#   'title': "Developers can't fix bad management (2020)",
#   'votes': 355},
#  {'link': 'https://www.bbc.co.uk/news/health-57417219',
#   'title': "'Miraculous' mosquito hack cuts dengue by 77%",
#   'votes': 285},
#  {'link': 'https://www.theawl.com/2013/09/i-am-an-object-of-internet-ridicule-ask-me-anything/',
#   'title': 'I am an object of internet ridicule, ask me anything (2013)',
#   'votes': 250},
#  {'link': 'https://venturebeat.com/2021/06/09/deepmind-says-reinforcement-learning-is-enough-to-reach-general-ai/',
#   'title': 'DeepMind says reinforcement learning is ‘enough’ to reach general '
#            'AI',
#   'votes': 228},
#  {'link': 'https://www.statista.com/statistics/1032048/value-us-dollar-since-1640/',
#   'title': 'Purchasing power of one US dollar in every year from 1635 to 2020',
#   'votes': 187},
#  {'link': 'https://www.quantamagazine.org/dna-jumps-between-animal-species-no-one-knows-how-often-20210609/',
#   'title': 'DNA jumps between animal species, but no one knows how often',
#   'votes': 186},
#  {'link': 'https://www.agweb.com/news/business/technology/robot-replace-need-farmers-go-inside-grain-bin',
#   'title': 'A robot to replace the need for farmers to go inside the grain bin',
#   'votes': 177},
#  {'link': 'https://www.philipotoole.com/rqlite-6-0-0-building-for-the-future/',
#   'title': 'Rqlite 6.0: the evolution of a distributed database design',
#   'votes': 176},
#  {'link': 'https://willhaley.com/blog/raspberry-pi-wifi-ethernet-bridge/',
#   'title': 'Raspberry Pi WiFi to ethernet bridge',
#   'votes': 161},
#  {'link': 'https://cerebras.net/product/',
#   'title': 'The Cerebras CS-2 wafer-scale engine (850k cores, 40 GB SRAM)',
#   'votes': 122},
#  {'link': 'https://tip.golang.org/doc/go1.17',
#   'title': 'Go 1.17 Beta',
#   'votes': 115},
#  {'link': 'https://www.explo.co/',
#   'title': 'Launch HN: Explo (YC W20) – Customer-facing dashboards and reports',
#   'votes': 108}]
